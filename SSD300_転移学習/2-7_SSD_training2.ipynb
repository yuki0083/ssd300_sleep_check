# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir("/content/drive/My Drive/ssd300_sleep_check")

# %%
# パッケージのimport
import os.path as osp
import random
import time
import glob

import cv2
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.init as init
import torch.optim as optim
import torch.utils.data as data

# %%
# 乱数のシードを設定
torch.manual_seed(1234)
np.random.seed(1234)
random.seed(1234)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("使用デバイス：", device)
# Out:
# 使用デバイス： cuda:0

# %% [markdown]
# ## globが認識されないのでmake_datapath_list()をここに書く

# %%
# 学習、検証の画像データとアノテーションデータへのファイルパスリストを作成する


def make_datapath_list(rootpath):
    """
    データへのパスを格納したリストを作成する。

    Parameters
    ----------
    rootpath : str
        データフォルダへのパス

    Returns
    -------
    ret : train_img_list, train_anno_list, val_img_list, val_anno_list
        データへのパスを格納したリスト
    """

    # 画像ファイルとアノテーションファイルへのパスのテンプレートを作成
    #imgpath_template = osp.join(rootpath, 'JPEGImages', '%s.jpg')
    #annopath_template = osp.join(rootpath, 'Annotations', '%s.xml')

    # 訓練と検証、それぞれのファイルのID（ファイル名）を取得する
    #train_id_names = osp.join(rootpath + 'ImageSets/Main/train.txt')
    #val_id_names = osp.join(rootpath + 'ImageSets/Main/val.txt')

    # 訓練データの画像ファイルとアノテーションファイルへのパスリストを作成
    """
    train_img_list = list()
    train_anno_list = list()
    for line in open(train_id_names):
        file_id = line.strip()  # 空白スペースと改行を除去
        img_path = (imgpath_template % file_id)  # 画像のパス
        anno_path = (annopath_template % file_id)  # アノテーションのパス
        train_img_list.append(img_path)  # リストに追加
        train_anno_list.append(anno_path)  # リストに追加
    """
    path_to_train_data = 'train/sleep_check_train2-PascalVOC-export/'
    train_img_list = glob.glob(rootpath + path_to_train_data + 'JPEGImages'+"/*")
    train_anno_list = glob.glob(rootpath + path_to_train_data + 'Annotations'+"/*")
    
    # 検証データの画像ファイルとアノテーションファイルへのパスリストを作成
    """
    val_img_list = list()
    val_anno_list = list()

    for line in open(val_id_names):
        file_id = line.strip()  # 空白スペースと改行を除去
        img_path = (imgpath_template % file_id)  # 画像のパス
        anno_path = (annopath_template % file_id)  # アノテーションのパス
        val_img_list.append(img_path)  # リストに追加
        val_anno_list.append(anno_path)  # リストに追加
    """
    path_to_val_data = 'val/sleep_check_val2-PascalVOC-export/'
    val_img_list = glob.glob(rootpath + path_to_val_data + 'JPEGImages'+"/*")
    val_anno_list = glob.glob(rootpath + path_to_val_data + 'Annotations'+"/*")
    
    return train_img_list, train_anno_list, val_img_list, val_anno_list

# %%
os.getcwd()
rootpath = os.getcwd()+"/data/annotation_data_2/"
rootpath
# Out:
# '/content/drive/My Drive/ssd300_sleep_check/data/annotation_data_2/'

# %%
# ファイルパスのリストを作成
rootpath = os.getcwd()+"/data/annotation_data_2/" #datasetを作るときのために絶対パスにしておく
train_img_list, train_anno_list, val_img_list, val_anno_list = make_datapath_list(
    rootpath)

# 動作確認
print(train_img_list[10])
print(val_img_list[10])
# Out:
# /content/drive/My Drive/ssd300_sleep_check/data/annotation_data_2/train/sleep_check_train2-PascalVOC-export/JPEGImages/10588052_02.jpg
# /content/drive/My Drive/ssd300_sleep_check/data/annotation_data_2/val/sleep_check_val2-PascalVOC-export/JPEGImages/10588087_01.jpg

# %% [markdown]
# # DatasetとDataLoaderを作成する

# %%
os.chdir('SSD300_transfer/')

# %%
from utils.ssd_model import  VOCDataset, DataTransform, Anno_xml2list, od_collate_fn#make_datapath_listを消去

# Datasetを作成
voc_classes = ['safe', 'caution']
color_mean = (104, 117, 123)  # (BGR)の色の平均値
input_size = 300  # 画像のinputサイズを300×300にする

train_dataset = VOCDataset(train_img_list, train_anno_list, phase="train", transform=DataTransform(
    input_size, color_mean), transform_anno=Anno_xml2list(voc_classes))

val_dataset = VOCDataset(val_img_list, val_anno_list, phase="val", transform=DataTransform(
    input_size, color_mean), transform_anno=Anno_xml2list(voc_classes))

#train_dataset.__getitem__(1)

# %% [markdown]
# ## batch_size を32→8→32

# %%
# DataLoaderを作成する
batch_size = 32

train_dataloader = data.DataLoader(
    train_dataset, batch_size=batch_size, shuffle=True, collate_fn=od_collate_fn)

val_dataloader = data.DataLoader(
    val_dataset, batch_size=batch_size, shuffle=False, collate_fn=od_collate_fn)

# 辞書オブジェクトにまとめる
dataloaders_dict = {"train": train_dataloader, "val": val_dataloader}

# %% [markdown]
# # ネットワークモデルの作成

# %%
from utils.ssd_model import SSD

# SSD300の設定
ssd_cfg = {
    'num_classes': 21,  # 背景クラスを含めた合計クラス数(読み込んで変)
    'input_size': 300,  # 画像の入力サイズ
    'bbox_aspect_num': [4, 6, 6, 6, 4, 4],  # 出力するDBoxのアスペクト比の種類
    'feature_maps': [38, 19, 10, 5, 3, 1],  # 各sourceの画像サイズ
    'steps': [8, 16, 32, 64, 100, 300],  # DBOXの大きさを決める
    'min_sizes': [30, 60, 111, 162, 213, 264],  # DBOXの大きさを決める
    'max_sizes': [60, 111, 162, 213, 264, 315],  # DBOXの大きさを決める
    'aspect_ratios': [[2], [2, 3], [2, 3], [2, 3], [2], [2]],
}

# SSDネットワークモデル
net = SSD(phase="train", cfg=ssd_cfg, transfer_class_num=3)
net
# Out:
# SSD(
#   (vgg): ModuleList(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#     (31): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(6, 6), dilation=(6, 6))
#     (32): ReLU(inplace=True)
#     (33): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1))
#     (34): ReLU(inplace=True)
#   )
#   (extras): ModuleList(
#     (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (2): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#     (3): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (4): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#     (5): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1))
#     (6): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#     (7): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1))
#   )
#   (L2Norm): L2Norm()
#   (loc): ModuleList(
#     (0): Conv2d(512, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Conv2d(1024, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (2): Conv2d(512, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): Conv2d(256, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): Conv2d(256, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): Conv2d(256, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (conf): ModuleList(
#     (0): Conv2d(512, 84, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Conv2d(1024, 126, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (2): Conv2d(512, 126, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): Conv2d(256, 126, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): Conv2d(256, 84, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): Conv2d(256, 84, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
# )

# %% [markdown]
# ## 学習済みデータの読み込み

# %%
state_dict = torch.load("./weights/ssd300_mAP_77.43_v2.pth")
net.load_state_dict(state_dict)
# Out:
# <All keys matched successfully>

# %% [markdown]
# ### conf層を３クラスに対応するように取り換え

# %%
net.conf[0] = nn.Conv2d(512, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
net.conf[1] = nn.Conv2d(1024, 18, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
net.conf[2] = nn.Conv2d(512, 18, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
net.conf[3] = nn.Conv2d(256, 18, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
net.conf[4] = nn.Conv2d(256, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
net.conf[5] = nn.Conv2d(256, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))

# %%
net.conf
# Out:
# ModuleList(
#   (0): Conv2d(512, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (1): Conv2d(1024, 18, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (2): Conv2d(512, 18, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (3): Conv2d(256, 18, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (4): Conv2d(256, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (5): Conv2d(256, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )

# %% [markdown]
# ## conf層の初期値を設定

# %%
# SSDの初期の重みを設定
# ssdのvgg部分に重みをロードする
#vgg_weights = torch.load('./weights/vgg16_reducedfc.pth')#vgg部分
#net.vgg.load_state_dict(vgg_weights)

# ssdのその他のネットワークの重みはHeの初期値で初期化

#Heの初期値を与える関数
def weights_init(m):
    if isinstance(m, nn.Conv2d):
        init.kaiming_normal_(m.weight.data)#Heの初期値
        if m.bias is not None:  # バイアス項がある場合は０
            nn.init.constant_(m.bias, 0.0)


# Heの初期値を適用
#net.extras.apply(weights_init)
#net.loc.apply(weights_init)
net.conf.apply(weights_init)

# GPUが使えるかを確認
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("使用デバイス：", device)

print('ネットワーク設定完了：学習済みの重みをロードしました')
# Out:
# 使用デバイス： cuda:0
# ネットワーク設定完了：学習済みの重みをロードしました

# %% [markdown]
# # 損失関数と最適化手法を定義する

# %%
#conf層のみ学習
net.conf.parameters()
# Out:
# <generator object Module.parameters at 0x7f38aa42a5c8>

# %%
from utils.ssd_model import MultiBoxLoss

# 損失関数の設定
criterion = MultiBoxLoss(jaccard_thresh=0.5, neg_pos=3, device=device)

# 最適化手法の設定
optimizer = optim.SGD([{'params':net.vgg.parameters(), 'lr':1e-4},
                       {'params':net.extras.parameters(), 'lr':1e-4},
                       {'params':net.L2Norm.parameters(), 'lr':1e-4},
                       {'params':net.loc.parameters(), 'lr':5e-4},
                       {'params':net.conf.parameters(), 'lr':1e-3}],momentum=0.9, weight_decay=5e-4)


#optimizer = optim.SGD(net.conf.parameters(), lr=1e-3,momentum=0.9, weight_decay=5e-4) #ハイパラメータ！！！

# %% [markdown]
# # 学習・検証を実施する

# %%
# モデルを学習させる関数を作成


def train_model(net, dataloaders_dict, criterion, optimizer, num_epochs):

    # GPUが使えるかを確認
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print("使用デバイス：", device)

    # ネットワークをGPUへ
    net.to(device)

    # ネットワークがある程度固定であれば、高速化させる
    torch.backends.cudnn.benchmark = True

    # イテレーションカウンタをセット
    iteration = 1
    epoch_train_loss = 0.0  # epochの損失和
    epoch_val_loss = 0.0  # epochの損失和
    logs = []

    # epochのループ
    for epoch in range(num_epochs+1):

        # 開始時刻を保存
        t_epoch_start = time.time()
        t_iter_start = time.time()

        print('-------------')
        print('Epoch {}/{}'.format(epoch+1, num_epochs))
        print('-------------')

        # epochごとの訓練と検証のループ
        for phase in ['train', 'val']:
            if phase == 'train':
                net.train()  # モデルを訓練モードに
                print('（train）')
            else:
                if((epoch+1) % 10 == 0):
                    net.eval()   # モデルを検証モードに
                    print('-------------')
                    print('（val）')
                else:
                    # 検証は10回に1回だけ行う
                    continue

            # データローダーからminibatchずつ取り出すループ
            for images, targets in dataloaders_dict[phase]:

                # GPUが使えるならGPUにデータを送る
                images = images.to(device)
                targets = [ann.to(device)
                           for ann in targets]  # リストの各要素のテンソルをGPUへ

                # optimizerを初期化
                optimizer.zero_grad()

                # 順伝搬（forward）計算
                with torch.set_grad_enabled(phase == 'train'):
                    # 順伝搬（forward）計算
                    outputs = net(images)

                    # 損失の計算
                    loss_l, loss_c = criterion(outputs, targets)
                    loss = loss_l + loss_c

                    # 訓練時はバックプロパゲーション
                    if phase == 'train':
                        loss.backward()  # 勾配の計算

                        # 勾配が大きくなりすぎると計算が不安定になるので、clipで最大でも勾配2.0に留める
                        nn.utils.clip_grad_value_(
                            net.parameters(), clip_value=2.0)

                        optimizer.step()  # パラメータ更新

                        if (iteration % 10 == 0):  # 10iterに1度、lossを表示
                            t_iter_finish = time.time()
                            duration = t_iter_finish - t_iter_start
                            print('イテレーション {} || Loss: {:.4f} || 10iter: {:.4f} sec.'.format(
                                iteration, loss.item(), duration))
                            t_iter_start = time.time()

                        epoch_train_loss += loss.item()
                        iteration += 1

                    # 検証時
                    else:
                        epoch_val_loss += loss.item()

        # epochのphaseごとのlossと正解率
        t_epoch_finish = time.time()
        print('-------------')
        print('epoch {} || Epoch_TRAIN_Loss:{:.4f} ||Epoch_VAL_Loss:{:.4f}'.format(
            epoch+1, epoch_train_loss, epoch_val_loss))
        print('timer:  {:.4f} sec.'.format(t_epoch_finish - t_epoch_start))
        t_epoch_start = time.time()

        # ログを保存
        log_epoch = {'epoch': epoch+1,
                     'train_loss': epoch_train_loss, 'val_loss': epoch_val_loss}
        logs.append(log_epoch)
        df = pd.DataFrame(logs)
        df.to_csv("log_output.csv")

        epoch_train_loss = 0.0  # epochの損失和
        epoch_val_loss = 0.0  # epochの損失和

        # ネットワークを保存する
        if ((epoch+1) % 10 == 0):
            torch.save(net.state_dict(), 'weights/ssd300_data2_fine' +
                       str(epoch+1) + '.pth')

# %%
# 学習・検証を実行する
num_epochs= 100  
train_model(net, dataloaders_dict, criterion, optimizer, num_epochs=num_epochs)
# Out:
# 使用デバイス： cuda:0
# -------------
# Epoch 1/100
# -------------
# （train）
# -------------
# epoch 1 || Epoch_TRAIN_Loss:55.9510 ||Epoch_VAL_Loss:0.0000
# timer:  22.6657 sec.
# -------------
# Epoch 2/100
# -------------
# （train）
# イテレーション 10 || Loss: 6.7683 || 10iter: 18.9661 sec.
# -------------
# epoch 2 || Epoch_TRAIN_Loss:38.2262 ||Epoch_VAL_Loss:0.0000
# timer:  19.3332 sec.
# -------------
# Epoch 3/100
# -------------
# （train）
# -------------
# epoch 3 || Epoch_TRAIN_Loss:31.7941 ||Epoch_VAL_Loss:0.0000
# timer:  17.9182 sec.
# -------------
# Epoch 4/100
# -------------
# （train）
# イテレーション 20 || Loss: 5.7867 || 10iter: 20.1449 sec.
# -------------
# epoch 4 || Epoch_TRAIN_Loss:30.2841 ||Epoch_VAL_Loss:0.0000
# timer:  20.5294 sec.
# -------------
# Epoch 5/100
# -------------
# （train）
# -------------
# epoch 5 || Epoch_TRAIN_Loss:28.1327 ||Epoch_VAL_Loss:0.0000
# timer:  18.2682 sec.
# -------------
# Epoch 6/100
# -------------
# （train）
# イテレーション 30 || Loss: 5.2557 || 10iter: 19.6566 sec.
# -------------
# epoch 6 || Epoch_TRAIN_Loss:27.0596 ||Epoch_VAL_Loss:0.0000
# timer:  20.0427 sec.
# -------------
# Epoch 7/100
# -------------
# （train）
# -------------
# epoch 7 || Epoch_TRAIN_Loss:25.7478 ||Epoch_VAL_Loss:0.0000
# timer:  19.1590 sec.
# -------------
# Epoch 8/100
# -------------
# （train）
# イテレーション 40 || Loss: 4.6426 || 10iter: 18.5426 sec.
# -------------
# epoch 8 || Epoch_TRAIN_Loss:25.2091 ||Epoch_VAL_Loss:0.0000
# timer:  18.9190 sec.
# -------------
# Epoch 9/100
# -------------
# （train）
# -------------
# epoch 9 || Epoch_TRAIN_Loss:24.4837 ||Epoch_VAL_Loss:0.0000
# timer:  19.5572 sec.
# -------------
# Epoch 10/100
# -------------
# （train）
# イテレーション 50 || Loss: 5.0930 || 10iter: 19.2244 sec.
# -------------
# （val）
# -------------
# epoch 10 || Epoch_TRAIN_Loss:24.4793 ||Epoch_VAL_Loss:8.8861
# timer:  74.5616 sec.
# -------------
# Epoch 11/100
# -------------
# （train）
# -------------
# epoch 11 || Epoch_TRAIN_Loss:23.2239 ||Epoch_VAL_Loss:0.0000
# timer:  18.6866 sec.
# -------------
# Epoch 12/100
# -------------
# （train）
# イテレーション 60 || Loss: 4.5858 || 10iter: 17.9930 sec.
# -------------
# epoch 12 || Epoch_TRAIN_Loss:22.8510 ||Epoch_VAL_Loss:0.0000
# timer:  18.3761 sec.
# -------------
# Epoch 13/100
# -------------
# （train）
# -------------
# epoch 13 || Epoch_TRAIN_Loss:22.7377 ||Epoch_VAL_Loss:0.0000
# timer:  19.5746 sec.
# -------------
# Epoch 14/100
# -------------
# （train）
# イテレーション 70 || Loss: 4.2794 || 10iter: 17.7549 sec.
# -------------
# epoch 14 || Epoch_TRAIN_Loss:22.2942 ||Epoch_VAL_Loss:0.0000
# timer:  18.1319 sec.
# -------------
# Epoch 15/100
# -------------
# （train）
# -------------
# epoch 15 || Epoch_TRAIN_Loss:22.0898 ||Epoch_VAL_Loss:0.0000
# timer:  17.7066 sec.
# -------------
# Epoch 16/100
# -------------
# （train）
# イテレーション 80 || Loss: 4.4020 || 10iter: 17.7323 sec.
# -------------
# epoch 16 || Epoch_TRAIN_Loss:21.6352 ||Epoch_VAL_Loss:0.0000
# timer:  18.1168 sec.
# -------------
# Epoch 17/100
# -------------
# （train）
# -------------
# epoch 17 || Epoch_TRAIN_Loss:21.2343 ||Epoch_VAL_Loss:0.0000
# timer:  17.7280 sec.
# -------------
# Epoch 18/100
# -------------
# （train）
# イテレーション 90 || Loss: 4.4610 || 10iter: 18.4377 sec.
# -------------
# epoch 18 || Epoch_TRAIN_Loss:21.7456 ||Epoch_VAL_Loss:0.0000
# timer:  18.8176 sec.
# -------------
# Epoch 19/100
# -------------
# （train）
# -------------
# epoch 19 || Epoch_TRAIN_Loss:21.1880 ||Epoch_VAL_Loss:0.0000
# timer:  18.4065 sec.
# -------------
# Epoch 20/100
# -------------
# （train）
# イテレーション 100 || Loss: 4.1903 || 10iter: 18.9463 sec.
# -------------
# （val）
# -------------
# epoch 20 || Epoch_TRAIN_Loss:20.8976 ||Epoch_VAL_Loss:8.1698
# timer:  20.7648 sec.
# -------------
# Epoch 21/100
# -------------
# （train）
# -------------
# epoch 21 || Epoch_TRAIN_Loss:21.3023 ||Epoch_VAL_Loss:0.0000
# timer:  18.9881 sec.
# -------------
# Epoch 22/100
# -------------
# （train）
# イテレーション 110 || Loss: 4.2921 || 10iter: 17.7659 sec.
# -------------
# epoch 22 || Epoch_TRAIN_Loss:20.8481 ||Epoch_VAL_Loss:0.0000
# timer:  18.1489 sec.
# -------------
# Epoch 23/100
# -------------
# （train）
# -------------
# epoch 23 || Epoch_TRAIN_Loss:20.9374 ||Epoch_VAL_Loss:0.0000
# timer:  18.6392 sec.
# -------------
# Epoch 24/100
# -------------
# （train）
# イテレーション 120 || Loss: 3.9910 || 10iter: 19.1919 sec.
# -------------
# epoch 24 || Epoch_TRAIN_Loss:20.1967 ||Epoch_VAL_Loss:0.0000
# timer:  19.5686 sec.
# -------------
# Epoch 25/100
# -------------
# （train）
# -------------
# epoch 25 || Epoch_TRAIN_Loss:20.3571 ||Epoch_VAL_Loss:0.0000
# timer:  19.7013 sec.
# -------------
# Epoch 26/100
# -------------
# （train）
# イテレーション 130 || Loss: 4.0879 || 10iter: 18.3422 sec.
# -------------
# epoch 26 || Epoch_TRAIN_Loss:20.0403 ||Epoch_VAL_Loss:0.0000
# timer:  18.7188 sec.
# -------------
# Epoch 27/100
# -------------
# （train）
# -------------
# epoch 27 || Epoch_TRAIN_Loss:19.8989 ||Epoch_VAL_Loss:0.0000
# timer:  18.8572 sec.
# -------------
# Epoch 28/100
# -------------
# （train）
# イテレーション 140 || Loss: 4.0362 || 10iter: 18.3423 sec.
# -------------
# epoch 28 || Epoch_TRAIN_Loss:19.7971 ||Epoch_VAL_Loss:0.0000
# timer:  18.7245 sec.
# -------------
# Epoch 29/100
# -------------
# （train）
# -------------
# epoch 29 || Epoch_TRAIN_Loss:19.7737 ||Epoch_VAL_Loss:0.0000
# timer:  18.4866 sec.
# -------------
# Epoch 30/100
# -------------
# （train）
# イテレーション 150 || Loss: 3.8956 || 10iter: 19.2463 sec.
# -------------
# （val）
# -------------
# epoch 30 || Epoch_TRAIN_Loss:19.5856 ||Epoch_VAL_Loss:7.8722
# timer:  21.0393 sec.
# -------------
# Epoch 31/100
# -------------
# （train）
# -------------
# epoch 31 || Epoch_TRAIN_Loss:19.4497 ||Epoch_VAL_Loss:0.0000
# timer:  18.8072 sec.
# -------------
# Epoch 32/100
# -------------
# （train）
# イテレーション 160 || Loss: 4.0099 || 10iter: 18.6012 sec.
# -------------
# epoch 32 || Epoch_TRAIN_Loss:19.5150 ||Epoch_VAL_Loss:0.0000
# timer:  18.9762 sec.
# -------------
# Epoch 33/100
# -------------
# （train）
# -------------
# epoch 33 || Epoch_TRAIN_Loss:19.3662 ||Epoch_VAL_Loss:0.0000
# timer:  18.2721 sec.
# -------------
# Epoch 34/100
# -------------
# （train）
# イテレーション 170 || Loss: 3.5930 || 10iter: 18.4071 sec.
# -------------
# epoch 34 || Epoch_TRAIN_Loss:18.7201 ||Epoch_VAL_Loss:0.0000
# timer:  18.7992 sec.
# -------------
# Epoch 35/100
# -------------
# （train）
# -------------
# epoch 35 || Epoch_TRAIN_Loss:18.9604 ||Epoch_VAL_Loss:0.0000
# timer:  18.9561 sec.
# -------------
# Epoch 36/100
# -------------
# （train）
# イテレーション 180 || Loss: 3.4078 || 10iter: 19.2426 sec.
# -------------
# epoch 36 || Epoch_TRAIN_Loss:18.4664 ||Epoch_VAL_Loss:0.0000
# timer:  19.6217 sec.
# -------------
# Epoch 37/100
# -------------
# （train）
# -------------
# epoch 37 || Epoch_TRAIN_Loss:19.1493 ||Epoch_VAL_Loss:0.0000
# timer:  19.6694 sec.
# -------------
# Epoch 38/100
# -------------
# （train）
# イテレーション 190 || Loss: 3.6364 || 10iter: 17.1439 sec.
# -------------
# epoch 38 || Epoch_TRAIN_Loss:18.3127 ||Epoch_VAL_Loss:0.0000
# timer:  17.5236 sec.
# -------------
# Epoch 39/100
# -------------
# （train）
# -------------
# epoch 39 || Epoch_TRAIN_Loss:18.4787 ||Epoch_VAL_Loss:0.0000
# timer:  19.6108 sec.
# -------------
# Epoch 40/100
# -------------
# （train）
# イテレーション 200 || Loss: 3.5602 || 10iter: 19.4773 sec.
# -------------
# （val）
# -------------
# epoch 40 || Epoch_TRAIN_Loss:18.5560 ||Epoch_VAL_Loss:7.5822
# timer:  21.2744 sec.
# -------------
# Epoch 41/100
# -------------
# （train）
# -------------
# epoch 41 || Epoch_TRAIN_Loss:18.7070 ||Epoch_VAL_Loss:0.0000
# timer:  18.9627 sec.
# -------------
# Epoch 42/100
# -------------
# （train）
# イテレーション 210 || Loss: 3.4689 || 10iter: 18.4600 sec.
# -------------
# epoch 42 || Epoch_TRAIN_Loss:18.2148 ||Epoch_VAL_Loss:0.0000
# timer:  18.8475 sec.
# -------------
# Epoch 43/100
# -------------
# （train）
# -------------
# epoch 43 || Epoch_TRAIN_Loss:18.5218 ||Epoch_VAL_Loss:0.0000
# timer:  18.6285 sec.
# -------------
# Epoch 44/100
# -------------
# （train）
# イテレーション 220 || Loss: 3.4246 || 10iter: 18.5284 sec.
# -------------
# epoch 44 || Epoch_TRAIN_Loss:18.0017 ||Epoch_VAL_Loss:0.0000
# timer:  18.9132 sec.
# -------------
# Epoch 45/100
# -------------
# （train）
# -------------
# epoch 45 || Epoch_TRAIN_Loss:17.5233 ||Epoch_VAL_Loss:0.0000
# timer:  18.0519 sec.
# -------------
# Epoch 46/100
# -------------
# （train）
# イテレーション 230 || Loss: 3.7116 || 10iter: 18.0204 sec.
# -------------
# epoch 46 || Epoch_TRAIN_Loss:17.7613 ||Epoch_VAL_Loss:0.0000
# timer:  18.3968 sec.
# -------------
# Epoch 47/100
# -------------
# （train）
# -------------
# epoch 47 || Epoch_TRAIN_Loss:17.9290 ||Epoch_VAL_Loss:0.0000
# timer:  17.9180 sec.
# -------------
# Epoch 48/100
# -------------
# （train）
# イテレーション 240 || Loss: 3.7224 || 10iter: 19.5234 sec.
# -------------
# epoch 48 || Epoch_TRAIN_Loss:18.3053 ||Epoch_VAL_Loss:0.0000
# timer:  19.8930 sec.
# -------------
# Epoch 49/100
# -------------
# （train）
# -------------
# epoch 49 || Epoch_TRAIN_Loss:17.8607 ||Epoch_VAL_Loss:0.0000
# timer:  19.1468 sec.
# -------------
# Epoch 50/100
# -------------
# （train）
# イテレーション 250 || Loss: 3.5392 || 10iter: 17.3227 sec.
# -------------
# （val）
# -------------
# epoch 50 || Epoch_TRAIN_Loss:17.4435 ||Epoch_VAL_Loss:7.4362
# timer:  19.1114 sec.
# -------------
# Epoch 51/100
# -------------
# （train）
# -------------
# epoch 51 || Epoch_TRAIN_Loss:17.3383 ||Epoch_VAL_Loss:0.0000
# timer:  18.3881 sec.
# -------------
# Epoch 52/100
# -------------
# （train）
# イテレーション 260 || Loss: 3.3327 || 10iter: 17.4014 sec.
# -------------
# epoch 52 || Epoch_TRAIN_Loss:17.4283 ||Epoch_VAL_Loss:0.0000
# timer:  17.7824 sec.
# -------------
# Epoch 53/100
# -------------
# （train）
# -------------
# epoch 53 || Epoch_TRAIN_Loss:17.3557 ||Epoch_VAL_Loss:0.0000
# timer:  18.3386 sec.
# -------------
# Epoch 54/100
# -------------
# （train）
# イテレーション 270 || Loss: 3.5942 || 10iter: 18.0385 sec.
# -------------
# epoch 54 || Epoch_TRAIN_Loss:17.3664 ||Epoch_VAL_Loss:0.0000
# timer:  18.4213 sec.
# -------------
# Epoch 55/100
# -------------
# （train）
# -------------
# epoch 55 || Epoch_TRAIN_Loss:17.7710 ||Epoch_VAL_Loss:0.0000
# timer:  18.5714 sec.
# -------------
# Epoch 56/100
# -------------
# （train）
# イテレーション 280 || Loss: 3.3695 || 10iter: 18.2541 sec.
# -------------
# epoch 56 || Epoch_TRAIN_Loss:17.1887 ||Epoch_VAL_Loss:0.0000
# timer:  18.6350 sec.
# -------------
# Epoch 57/100
# -------------
# （train）
# -------------
# epoch 57 || Epoch_TRAIN_Loss:17.2912 ||Epoch_VAL_Loss:0.0000
# timer:  18.7152 sec.
# -------------
# Epoch 58/100
# -------------
# （train）
# イテレーション 290 || Loss: 3.6938 || 10iter: 18.2642 sec.
# -------------
# epoch 58 || Epoch_TRAIN_Loss:17.4102 ||Epoch_VAL_Loss:0.0000
# timer:  18.6421 sec.
# -------------
# Epoch 59/100
# -------------
# （train）
# -------------
# epoch 59 || Epoch_TRAIN_Loss:17.0043 ||Epoch_VAL_Loss:0.0000
# timer:  18.2636 sec.
# -------------
# Epoch 60/100
# -------------
# （train）
# イテレーション 300 || Loss: 3.3025 || 10iter: 18.1801 sec.
# -------------
# （val）
# -------------
# epoch 60 || Epoch_TRAIN_Loss:17.0526 ||Epoch_VAL_Loss:7.6025
# timer:  19.9955 sec.
# -------------
# Epoch 61/100
# -------------
# （train）
# -------------
# epoch 61 || Epoch_TRAIN_Loss:16.9081 ||Epoch_VAL_Loss:0.0000
# timer:  18.2946 sec.
# -------------
# Epoch 62/100
# -------------
# （train）
# イテレーション 310 || Loss: 3.0332 || 10iter: 19.1858 sec.
# -------------
# epoch 62 || Epoch_TRAIN_Loss:16.6396 ||Epoch_VAL_Loss:0.0000
# timer:  19.5639 sec.
# -------------
# Epoch 63/100
# -------------
# （train）
# -------------
# epoch 63 || Epoch_TRAIN_Loss:16.6023 ||Epoch_VAL_Loss:0.0000
# timer:  17.8191 sec.
# -------------
# Epoch 64/100
# -------------
# （train）
# イテレーション 320 || Loss: 3.0962 || 10iter: 17.6913 sec.
# -------------
# epoch 64 || Epoch_TRAIN_Loss:16.3770 ||Epoch_VAL_Loss:0.0000
# timer:  18.0753 sec.
# -------------
# Epoch 65/100
# -------------
# （train）
# -------------
# epoch 65 || Epoch_TRAIN_Loss:16.6374 ||Epoch_VAL_Loss:0.0000
# timer:  18.5005 sec.
# -------------
# Epoch 66/100
# -------------
# （train）
# イテレーション 330 || Loss: 2.9751 || 10iter: 18.5038 sec.
# -------------
# epoch 66 || Epoch_TRAIN_Loss:16.2702 ||Epoch_VAL_Loss:0.0000
# timer:  18.8904 sec.
# -------------
# Epoch 67/100
# -------------
# （train）
# -------------
# epoch 67 || Epoch_TRAIN_Loss:16.7058 ||Epoch_VAL_Loss:0.0000
# timer:  19.1883 sec.
# -------------
# Epoch 68/100
# -------------
# （train）
# イテレーション 340 || Loss: 3.4008 || 10iter: 18.4058 sec.
# -------------
# epoch 68 || Epoch_TRAIN_Loss:16.6424 ||Epoch_VAL_Loss:0.0000
# timer:  18.7866 sec.
# -------------
# Epoch 69/100
# -------------
# （train）
# -------------
# epoch 69 || Epoch_TRAIN_Loss:16.3942 ||Epoch_VAL_Loss:0.0000
# timer:  17.6507 sec.
# -------------
# Epoch 70/100
# -------------
# （train）
# イテレーション 350 || Loss: 3.1785 || 10iter: 18.8697 sec.
# -------------
# （val）
# -------------
# epoch 70 || Epoch_TRAIN_Loss:16.6641 ||Epoch_VAL_Loss:7.5140
# timer:  20.6773 sec.
# -------------
# Epoch 71/100
# -------------
# （train）
# -------------
# epoch 71 || Epoch_TRAIN_Loss:17.0059 ||Epoch_VAL_Loss:0.0000
# timer:  19.9186 sec.
# -------------
# Epoch 72/100
# -------------
# （train）
# イテレーション 360 || Loss: 3.1280 || 10iter: 18.3130 sec.
# -------------
# epoch 72 || Epoch_TRAIN_Loss:16.1255 ||Epoch_VAL_Loss:0.0000
# timer:  18.6938 sec.
# -------------
# Epoch 73/100
# -------------
# （train）
# -------------
# epoch 73 || Epoch_TRAIN_Loss:16.5225 ||Epoch_VAL_Loss:0.0000
# timer:  19.9115 sec.
# -------------
# Epoch 74/100
# -------------
# （train）
# イテレーション 370 || Loss: 3.0598 || 10iter: 18.6188 sec.
# -------------
# epoch 74 || Epoch_TRAIN_Loss:16.0504 ||Epoch_VAL_Loss:0.0000
# timer:  18.9991 sec.
# -------------
# Epoch 75/100
# -------------
# （train）
# -------------
# epoch 75 || Epoch_TRAIN_Loss:15.9357 ||Epoch_VAL_Loss:0.0000
# timer:  18.4705 sec.
# -------------
# Epoch 76/100
# -------------
# （train）
# イテレーション 380 || Loss: 3.1957 || 10iter: 18.3566 sec.
# -------------
# epoch 76 || Epoch_TRAIN_Loss:16.5185 ||Epoch_VAL_Loss:0.0000
# timer:  18.7358 sec.
# -------------
# Epoch 77/100
# -------------
# （train）
# -------------
# epoch 77 || Epoch_TRAIN_Loss:16.3869 ||Epoch_VAL_Loss:0.0000
# timer:  19.0581 sec.
# -------------
# Epoch 78/100
# -------------
# （train）
# イテレーション 390 || Loss: 3.4192 || 10iter: 18.7093 sec.
# -------------
# epoch 78 || Epoch_TRAIN_Loss:16.1188 ||Epoch_VAL_Loss:0.0000
# timer:  19.0867 sec.
# -------------
# Epoch 79/100
# -------------
# （train）
# -------------
# epoch 79 || Epoch_TRAIN_Loss:16.2582 ||Epoch_VAL_Loss:0.0000
# timer:  19.0730 sec.
# -------------
# Epoch 80/100
# -------------
# （train）
# イテレーション 400 || Loss: 3.2394 || 10iter: 18.0787 sec.
# -------------
# （val）
# -------------
# epoch 80 || Epoch_TRAIN_Loss:15.7022 ||Epoch_VAL_Loss:7.5436
# timer:  19.8848 sec.
# -------------
# Epoch 81/100
# -------------
# （train）
# -------------
# epoch 81 || Epoch_TRAIN_Loss:16.3290 ||Epoch_VAL_Loss:0.0000
# timer:  18.6129 sec.
# -------------
# Epoch 82/100
# -------------
# （train）
# イテレーション 410 || Loss: 2.9967 || 10iter: 18.8544 sec.
# -------------
# epoch 82 || Epoch_TRAIN_Loss:15.7257 ||Epoch_VAL_Loss:0.0000
# timer:  19.2377 sec.
# -------------
# Epoch 83/100
# -------------
# （train）
# -------------
# epoch 83 || Epoch_TRAIN_Loss:16.3977 ||Epoch_VAL_Loss:0.0000
# timer:  19.2909 sec.
# -------------
# Epoch 84/100
# -------------
# （train）
# イテレーション 420 || Loss: 3.4156 || 10iter: 17.6147 sec.
# -------------
# epoch 84 || Epoch_TRAIN_Loss:16.1577 ||Epoch_VAL_Loss:0.0000
# timer:  18.0003 sec.
# -------------
# Epoch 85/100
# -------------
# （train）
# -------------
# epoch 85 || Epoch_TRAIN_Loss:15.9956 ||Epoch_VAL_Loss:0.0000
# timer:  17.8508 sec.
# -------------
# Epoch 86/100
# -------------
# （train）
# イテレーション 430 || Loss: 3.1865 || 10iter: 17.6379 sec.
# -------------
# epoch 86 || Epoch_TRAIN_Loss:16.0592 ||Epoch_VAL_Loss:0.0000
# timer:  18.0216 sec.
# -------------
# Epoch 87/100
# -------------
# （train）
# -------------
# epoch 87 || Epoch_TRAIN_Loss:16.4240 ||Epoch_VAL_Loss:0.0000
# timer:  19.5494 sec.
# -------------
# Epoch 88/100
# -------------
# （train）
# イテレーション 440 || Loss: 3.2075 || 10iter: 18.9084 sec.
# -------------
# epoch 88 || Epoch_TRAIN_Loss:15.8511 ||Epoch_VAL_Loss:0.0000
# timer:  19.2988 sec.
# -------------
# Epoch 89/100
# -------------
# （train）
# -------------
# epoch 89 || Epoch_TRAIN_Loss:15.5183 ||Epoch_VAL_Loss:0.0000
# timer:  18.7109 sec.
# -------------
# Epoch 90/100
# -------------
# （train）
# イテレーション 450 || Loss: 3.0760 || 10iter: 17.7061 sec.
# -------------
# （val）
# -------------
# epoch 90 || Epoch_TRAIN_Loss:15.5943 ||Epoch_VAL_Loss:7.8331
# timer:  19.5199 sec.
# -------------
# Epoch 91/100
# -------------
# （train）
# -------------
# epoch 91 || Epoch_TRAIN_Loss:16.0162 ||Epoch_VAL_Loss:0.0000
# timer:  18.9278 sec.
# -------------
# Epoch 92/100
# -------------
# （train）
# イテレーション 460 || Loss: 3.1382 || 10iter: 18.6039 sec.
# -------------
# epoch 92 || Epoch_TRAIN_Loss:15.5074 ||Epoch_VAL_Loss:0.0000
# timer:  18.9782 sec.
# -------------
# Epoch 93/100
# -------------
# （train）
# -------------
# epoch 93 || Epoch_TRAIN_Loss:15.6783 ||Epoch_VAL_Loss:0.0000
# timer:  18.6135 sec.
# -------------
# Epoch 94/100
# -------------
# （train）
# イテレーション 470 || Loss: 2.9723 || 10iter: 17.6140 sec.
# -------------
# epoch 94 || Epoch_TRAIN_Loss:15.4440 ||Epoch_VAL_Loss:0.0000
# timer:  18.0082 sec.
# -------------
# Epoch 95/100
# -------------
# （train）
# -------------
# epoch 95 || Epoch_TRAIN_Loss:15.7775 ||Epoch_VAL_Loss:0.0000
# timer:  18.3478 sec.
# -------------
# Epoch 96/100
# -------------
# （train）
# イテレーション 480 || Loss: 2.9839 || 10iter: 17.6953 sec.
# -------------
# epoch 96 || Epoch_TRAIN_Loss:15.3980 ||Epoch_VAL_Loss:0.0000
# timer:  18.0792 sec.
# -------------
# Epoch 97/100
# -------------
# （train）
# -------------
# epoch 97 || Epoch_TRAIN_Loss:15.5592 ||Epoch_VAL_Loss:0.0000
# timer:  18.4430 sec.
# -------------
# Epoch 98/100
# -------------
# （train）
# イテレーション 490 || Loss: 3.3452 || 10iter: 20.4319 sec.
# -------------
# epoch 98 || Epoch_TRAIN_Loss:15.7690 ||Epoch_VAL_Loss:0.0000
# timer:  20.8145 sec.
# -------------
# Epoch 99/100
# -------------
# （train）
# -------------
# epoch 99 || Epoch_TRAIN_Loss:15.9253 ||Epoch_VAL_Loss:0.0000
# timer:  19.3435 sec.
# -------------
# Epoch 100/100
# -------------
# （train）
# イテレーション 500 || Loss: 2.6314 || 10iter: 18.3612 sec.
# -------------
# （val）
# -------------
# epoch 100 || Epoch_TRAIN_Loss:14.9492 ||Epoch_VAL_Loss:7.6767
# timer:  20.1825 sec.
# -------------
# Epoch 101/100
# -------------
# （train）
# -------------
# epoch 101 || Epoch_TRAIN_Loss:15.8171 ||Epoch_VAL_Loss:0.0000
# timer:  19.2276 sec.

# %% [markdown]
# 以上
